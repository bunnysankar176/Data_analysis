# %%
#sand-box-api
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'2700',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fa24e2e8-4330-40df-97d3-159ea2ebfdb3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:15:52.954Z', 'error_code': 0, 'error_message': None, 'elapsed': 0, 'credit_count': 1, 'notice': None}, 'data': [{'id': 4396, 'name': 'l0ugar96px', 'symbol': 'h2p81pnxpw', 'slug': 'qi9ry5mzoy', 'cmc_rank': 5280, 'num_market_pairs': 4994, 'circulating_supply': 1536, 'total_supply': 3864, 'max_supply': 4153, 'infinite_supply': None, 'last_updated': '2024-02-20T06:15:52.954Z', 'date_added': '2024-02-20T06:15:52.954Z', 'tags': ['pp5rvqnf8m', 'uzluwy60q0t', 'j08jjz4jjc', '33j2vxnnrj4', 'x7tzoign4n8', 'i3ftiu8d90h', 'j8ja9zn0pm', '9w7cc1lqeet', 'nakkuinx2k', 'l55qp7nafa'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.1287372200932264, 'volume_24h': 6337, 'volume_change_24h': 0.583451758868246, 'percent_change_1h': 0.6889782908184774, 'percent_change_24h': 0.754490167459906, 'percent_change_7d': 0.15467540494560073, 'market_cap': 0.036427013542824405, 'market_cap_dominance': 
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  4396   l0ugar96px   h2p81pnxpw    qi9ry5mzoy      5280              4994
# 1  3737  n8sv16qjgkd  0vbedgm58mk   qwiain3iyfh      3815               746
# 2  4820  a9ssz3bri0w   n6goh5jvda   y3kflf9sypc      3945              9579
# 3  2096  8vt3bbqv5nr  55fm38d6blm   3mu31qa6kjp       400              6233
# 4   639   zt5832cxee  6u6xu9je20h   vgplxhk8lfk      4525              2441
# 5   677  06t9v5d8wqq  vnvh6axraag   fsdex33rddd      5609              1377
# 6  7639   y3mdxx8umb  4sx0683bj53    gtxsg5pwn8      2984              2145
# 7  3677  b0zkh70y97r   aozt8a4s5h   vx5vqnb5iyc      5209              1515
# 8  5938  na46x9sg0gj   77admc9cht  1t8koiomyo0h      7296              8851
# 9  5874  9fgkmsg7a1l  wuhmq5jb7zj   5znxccnet0d      8496              3888
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %%
#pro-api
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fa24e2e8-4330-40df-97d3-159ea2ebfdb3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:00:44.838Z', 'error_code': 0, 'error_message': None, 'elapsed': 12, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 0       1        Bitcoin    BTC        bitcoin             10821
# 1    1027       Ethereum    ETH       ethereum              8428
# 2     825    Tether USDt   USDT         tether             74897
# 3    1839            BNB    BNB            bnb              2070
# 4    5426         Solana    SOL         solana               626
# ..    ...            ...    ...            ...               ...
# 95   7548          WEMIX  WEMIX          wemix                52
# 96   1659         Gnosis    GNO     gnosis-gno               169
# 97  13631  Manta Network  MANTA  manta-network                84
# 98   1042        Siacoin     SC        siacoin                95
# 99  17799         Axelar    AXL         axelar                82
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ...

# %% [markdown]
# RandomFox API (without API key)

# %%
import requests

# %%
page = requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/50.jpg","link":"https:\/\/randomfox.ca\/?i=50"}

# %%
fox = page.json()
image = fox['image']
print(image)
# Out:
# https://randomfox.ca/images/50.jpg

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=260b5bc45c64414e67ff229ff9423e0a'  #actual url
parameters = {
  'start':'1',
  'limit':'2767',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7c62141e221fe9874c26e8e5ebd1886b',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1708419600, 'main': {'temp': 261.57, 'feels_like': 255.16, 'temp_min': 261.57, 'temp_max': 265.88, 'pressure': 1031, 'sea_level': 1031, 'grnd_level': 1010, 'humidity': 97, 'temp_kf': -4.31}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.5, 'deg': 191, 'gust': 6.27}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 09:00:00'}, {'dt': 1708430400, 'main': {'temp': 265.15, 'feels_like': 259.18, 'temp_min': 265.15, 'temp_max': 268.02, 'pressure': 1029, 'sea_level': 1029, 'grnd_level': 1009, 'humidity': 92, 'temp_kf': -2.87}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.84, 'deg': 184, 'gust': 7.31}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 12:00:00'}, {'dt': 1708441200, 'main': {'temp': 265.32, 'f
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['list'])
norm
# Out:
#             dt                                            weather  visibility  \
# 0   1708419600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1708430400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 2   1708441200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 3   1708452000  [{'id': 804, 'main': 'Clouds', 'description': ...        9777
# 4   1708462800  [{'id': 804, 'main': 'Clouds', 'description': ...        7943
# 5   1708473600  [{'id': 804, 'main': 'Clouds', 'description': ...        9399
# 6   1708484400  [{'id': 804, 'main': 'Clouds', 'description': ...        9659
# 7   1708495200  [{'id': 804, 'main': 'Clouds', 'description': ...        4796
# 8   1708506000  [{'id': 600, 'main': 'Snow', 'description': 'l...         437
# 9   1708516800  [{'id': 600, 'main': 'Snow', 'description': 'l...         568
# 10  1708527600  [{'id': 600, 'main': 'Snow', 'description': 'l...         412
# ...

# %%
#Google translator
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

payload = {
	"q": "hi how are you",
	"target": "te",
	"source": "en"
}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"Accept-Encoding": "application/gzip",
	"X-RapidAPI-Key": "eb0b34614bmsh3014727d4bd0b00p18ca7djsnbdfb52b36360",
	"X-RapidAPI-Host": "google-translate1.p.rapidapi.com"
}

response = requests.post(url, data=payload, headers=headers)

print(response.json())
# Out:
# {'data': {'translations': [{'translatedText': 'హాయ్ ఎలా ఉన్నారు'}]}}
